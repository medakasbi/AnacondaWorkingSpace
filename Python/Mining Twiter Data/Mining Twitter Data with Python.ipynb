# %% [markdown]
# <a href= https://marcobonzanini.com/2015/03/02/mining-twitter-data-with-python-part-1/ > Mining Twitter Data with Python (Part 1: Collecting data) </a>

# %%
import tweepy
from tweepy import OAuthHandler
import json

# %%
my_key = 'r3NlNTNnYhzLeQ15xv6ueoPkO'
my_secret = 'CYcewulrk2qfdqmPk0Ai8aGj1Skn0jdSKOvNOljV6XjSjzfo6D'
access_token = "2269112941-iD5PEMGXmfGgUPotXzJFd2uwohtwyacOj3OH66v"
access_secret = 'h0qOepuTWS9X3HEZThmiAQySseex3ustvc32wBriBvz5Y'

auth = OAuthHandler(my_key, my_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

# %%
for status in tweepy.Cursor(api.home_timeline).items(10):
    # Process a single status 
    print(json.dumps(status._json))
# Out:
# {"created_at": "Sat Dec 01 19:14:09 +0000 2018", "id": 1068946369677795328, "id_str": "1068946369677795328", "text": "#LTS @fabriceeboue  : \u00ab Le comique c\u2019est d\u2019avoir du recul sur soi. Quand on pr\u00e9tend avoir du recul sur tout, on com\u2026 https://t.co/YOChvBCYeA", "truncated": true, "entities": {"hashtags": [{"text": "LTS", "indices": [0, 4]}], "symbols": [], "user_mentions": [{"screen_name": "fabriceeboue", "name": "fabrice ebou\u00e9", "id": 371983583, "id_str": "371983583", "indices": [5, 18]}], "urls": [{"url": "https://t.co/YOChvBCYeA", "expanded_url": "https://twitter.com/i/web/status/1068946369677795328", "display_url": "twitter.com/i/web/status/1\u2026", "indices": [117, 140]}]}, "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 362477988, "id_str":
# ...

# %%
#  if we want to have a list of all our followers
for friend in tweepy.Cursor(api.friends).items():
    print(json.dumps(friend._json))
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-4-2953b9f0b5bb> in <module>
#       1 #  if we want to have a list of all our followers
# ----> 2 for friend in tweepy.Cursor(api.friends).items():
#       3     print(json.dumps(friend._json))
#
# ~\Anaconda3\lib\site-packages\tweepy\cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#      51     def next(self):
#
# ~\Anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     195         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     196             # Reached end of current page, get the next page...
# --> 197             self.current_page = self.page_iterator.next()
#     198             self.page_index = -1
#     199         self.page_index += 1
#
# ...

# %%
# a list of all our tweets
for tweet in tweepy.Cursor(api.user_timeline).items():
    print(json.dumps(tweet._json))
# Out:
# {"created_at": "Sat Jul 07 05:21:31 +0000 2018", "id": 1015465817130053634, "id_str": "1015465817130053634", "text": "Cardano (ADA) Threatening Cryptocurrency Market Leaders @EtherWorldNews https://t.co/FmHPaDcHAy", "truncated": false, "entities": {"hashtags": [], "symbols": [], "user_mentions": [{"screen_name": "EtherWorldNews", "name": "Ethereum World News", "id": 875119592154304512, "id_str": "875119592154304512", "indices": [56, 71]}], "urls": [{"url": "https://t.co/FmHPaDcHAy", "expanded_url": "https://ethereumworldnews.com/cardano-ada-threatening-cryptocurrency-market-leaders/", "display_url": "ethereumworldnews.com/cardano-ada-th\u2026", "indices": [72, 95]}]}, "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 2269112941, "id_str": "2269112941", "name": "Mohamed Akasbi",
# ...

# %% [markdown]
# # Streaming
# In case we want to “keep the connection open”, and gather all the upcoming tweets about a particular event, the streaming API is what we need. We need to extend the StreamListener() to customise the way we process the incoming data. A working example that gathers all the new tweets with the #trump hashtag:

# %%
from tweepy import Stream
from tweepy.streaming import StreamListener

# class MyListener(StreamListener):
#     def on_data(self, data):
#         try:
#             with open('python.json', 'a') as f:
#                 f.write(data)
#                 return True
#         except BaseException as e:
#             print("Error on_data : %" % str(e))
#         return True
#     def on_error(self, status):
#         print(status)
#         return True
    
# hashtag = '#Trump'
# twitter_stream = Stream(auth, MyListener())
# twitter_stream.filter(track = [hashtag])

# %% [markdown]
# # Mining Twitter Data with Python (Part 2: Text Pre-processing)

# %%
 with open('python.json', 'r') as f:
        line = f.readline() # read only the first tweet/line
        tweet = json.loads(line) # load it bas python Dict
        print(json.dumps(tweet, indent = 4))
# Out:
# {
#     "created_at": "Sat Dec 01 19:02:22 +0000 2018",
#     "id": 1068943404590133249,
#     "id_str": "1068943404590133249",
#     "text": "#Brexit, #CambridgeAnalytica, #Trump, #AltRight, #UltraNationalism, #UltraConservatism, Anti-#EU sentiment, Angry O\u2026 https://t.co/IC3NKORD3n",
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "truncated": true,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "in_reply_to_screen_name": null,
#     "user": {
#         "id": 739124657228484608,
#         "id_str": "739124657228484608",
#         "name": "bennjamin",
#         "screen_name": "bennjmin",
#         "location": null,
#         "url": null,
# ...

# %%
print(len('python.json'))
# Out:
# 11

# %%
import nltk

# %%
from nltk.tokenize import word_tokenize

tweet = 'RT @marcobonzanini: just an example! :D http://example.com #NLP'

print(word_tokenize(tweet))
# Out:
# ['RT', '@', 'marcobonzanini', ':', 'just', 'an', 'example', '!', ':', 'D', 'http', ':', '//example.com', '#', 'NLP']

# %%
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\asus-A9\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
text = "Filtering data is one of the very basic operation when you work with data. You want to remove a part of the data that is invalid or simply you’re not interested in. Or, you want to zero in on a particular part of the data you want to know more about. Of course, dplyr has ’filter()’ function to do such filtering, but there is even more. With dplyr you can do the kind of filtering, which could be hard to perform or complicated to construct with tools like SQL and traditional BI tools, in such a simple and more intuitive way."

# %%
len(word_tokenize(text))
# Out:
# 117

# %%
len(set(word_tokenize(text)))
# Out:
# 70
