# %% [markdown]
# https://stackoverflow.com/questions/25228106/how-to-extract-text-from-an-existing-docx-file-using-python-docx

# %%
import docx
import os

# %%
def gettext(filename):
    doc = docx.Document(filename)
    fulltext = []
    for par in doc.paragraphs:
        print(par.text)

    return '\n'.join(fulltext)

# %%
#os.getcwd()

# %%
# filename = os.getcwd() + '\\UD1_Français_pratique_6aep'
filename ='C:/Users/asus-A9/Documents/GitHub/\
AnacondaWorkingSpace/Python/docx/UD1_Français_pratique_6aep.docx'

# %%
print(gettext(filename))
# Out:
# Sous compétence
# La première unité est consacrée à l’évaluation diagnostique, à la remédiation et à la consolidation des acquis.
#
# Thème   :	La rentrée scolaire
# Projet 	Elaborer un dossier sur l’école
#
# Semaines	1	2	3	4	5
# Com actes de langage	Passation et correction du test diagnostique
# 	Séance 1 et 2
# Evaluation :
# -  Se présenter
# - Présenter 	Séance 1 et 2
# Consolidation et remédiation :
# -  Se présenter
# - Présenter 	Séance 1 et 2
# Evaluation :
# - Demander / donner des informations
# 	Séance 1 et 2
# Consolidation et remédiation :
# - Demander / donner des informations
# Lecture		Séance 1 et 2
# Correction et remédiation
# Compréhension de l’écrit 1 et 2
# 	Séance 1 et 2
# -Bien dire un texte
# Grammaire		Correction et remédiation :
# Les types de phrases	Correction et remédiation :
# Les formes de phrases.	Correction et remédiation :
# GNS et GV	Correction et remédiation :
# COD et COI
# Conjugaison		Correction et remédiation :
# ...

# %%
doc = docx.Document(filename)
par = doc.paragraphs[5]
dir(par)
print(par.text)
#  'runs',
#  'style',
#  'text']

# %%
# Out:
# '\x00'
