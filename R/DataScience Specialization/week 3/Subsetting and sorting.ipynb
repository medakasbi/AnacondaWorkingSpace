# %%
set.seed(13435)
x <- data.frame("var1" = sample(1:5),
               "var2" = sample(6:10),
               "var3" = sample(11:15))
x <- x[sample(1:5),]
x$var2[c(1, 3)] = NA
x
# Out:
#   var1 var2 var3
# 1 2    NA   15
# 4 1    10   11
# 2 3    NA   12
# 3 5     6   14
# 5 4     9   13

# %%
class(x[1])
x[1]
# Out:
# [1] "data.frame"
#   var1
# 1 2
# 4 1
# 2 3
# 3 5
# 5 4

# %%
class(x[[1]])
x[[1]]
# Out:
# [1] "integer"
# [1] 2 1 3 5 4

# %%
class(x[,1])
x[,1]
# Out:
# [1] "integer"
# [1] 2 1 3 5 4

# %%
x["var1"]
# Out:
#   var1
# 1 2
# 4 1
# 2 3
# 3 5
# 5 4

# %%
x[, "var1"]
# Out:
# [1] 2 1 3 5 4

# %%
x[1:2]
# Out:
#   var1 var2
# 1 2    NA
# 4 1    10
# 2 3    NA
# 3 5     6
# 5 4     9

# %%
x[1:2,]
# Out:
#   var1 var2 var3
# 1 2    NA   15
# 4 1    10   11

# %%
x[1:3,]
# Out:
#   var1 var2 var3
# 1 2    NA   15
# 4 1    10   11
# 2 3    NA   12

# %%
o = x[1, 1]
print(o)
class(o)
# Out:
# [1] 2
# [1] "integer"

# %%
class(x[[1, 1]])
# Out:
# [1] "integer"

# %%
o = x[1:2, 1:3]
print(o)
class(o)
# Out:
#   var1 var2 var3
# 1    2   NA   15
# 4    1   10   11
# [1] "data.frame"

# %%
o = x[[1:2, 1:3]]
print(o)
class(o)
# Out:
# Error in .subset2(x, ..2, exact = exact): recursive indexing failed at level 2
#
# Traceback:
#
# 1. x[[1:2, 1:3]]
# 2. `[[.data.frame`(x, 1:2, 1:3)

# %%
x
# Out:
#   var1 var2 var3
# 1 2    NA   15
# 4 1    10   11
# 2 3    NA   12
# 3 5     6   14
# 5 4     9   13

# %%
select(x, vr1, var2)
# Out:
# Error in select(x, vr1, var2): could not find function "select"
# Traceback:

# %%
getwd()
# Out:
# [1] "C:/Users/asus-A9/Documents/GitHub/AnacondaWorkingSpace/R/DataScience Specialization/week 3"

# %%
dir_ = 'C:/Users/asus-A9/Documents/GitHub/AnacondaWorkingSpace/R/DataScience Specialization'

file_location = file.path(dir_, 'Data/ss0pid.csv')
#file_location
df = read.csv(file_location)

# %%
dim(df)
# Out:
# [1] 14931   239

# %%
names(df)
# Out:
#   [1] "RT"       "SERIALNO" "SPORDER"  "PUMA"     "ST"       "ADJUST"
#   [7] "PWGTP"    "AGEP"     "CIT"      "COW"      "DDRS"     "DEYE"
#  [13] "DOUT"     "DPHY"     "DREM"     "DWRK"     "ENG"      "FER"
#  [19] "GCL"      "GCM"      "GCR"      "INTP"     "JWMNP"    "JWRIP"
#  [25] "JWTR"     "LANX"     "MAR"      "MIG"      "MIL"      "MILY"
#  [31] "MLPA"     "MLPB"     "MLPC"     "MLPD"     "MLPE"     "MLPF"
#  [37] "MLPG"     "MLPH"     "MLPI"     "MLPJ"     "MLPK"     "NWAB"
#  [43] "NWAV"     "NWLA"     "NWLK"     "NWRE"     "OIP"      "PAP"
#  [49] "REL"      "RETP"     "SCH"      "SCHG"     "SCHL"     "SEMP"
#  [55] "SEX"      "SSIP"     "SSP"      "WAGP"     "WKHP"     "WKL"
#  [61] "WKW"      "YOEP"     "UWRK"     "ANC"      "ANC1P"    "ANC2P"
#  [67] "DECADE"   "DRIVESP"  "DS"       "ESP"      "ESR"      "HISP"
#  [73] "INDP"     "JWAP"     "JWDP"     "LANP"     "MIGPUMA"  "MIGSP"
#  [79] "MSP"      "NAICSP"   "NATIVITY" "NOP"      "OC"       "OCCP"
# ...

# %%
df[1:2, 'pwgtp1']
# Out:
# NULL

# %%
df[df$'pwgtp71' == df$'pwgtp79' ,]
# Out:
#       RT  SERIALNO SPORDER PUMA ST  ADJUST  PWGTP AGEP CIT COW ... pwgtp71
# 116   P    14631   1       500  16  1015675  18   54   1    1  ...   5
# 147   P    17229   5       500  16  1015675  80   22   1    1  ...  79
# 162   P    19260   3       200  16  1015675 111    7   1   NA  ... 119
# 261   P    29982   1       100  16  1015675  22   48   1    1  ...  21
# 468   P    46981   1       500  16  1015675 153   26   1    7  ... 167
# 516   P    51315   1       300  16  1015675  19   64   1   NA  ...  19
# 525   P    52121   1       100  16  1015675  27   56   1    1  ...   7
# 586   P    56287   2       600  16  1015675 105   51   1   NA  ... 106
# 714   P    71254   1       800  16  1015675  44   58   1    4  ...  42
# 817   P    79817   1       300  16  1015675  55   38   1   NA  ...  23
# 863   P    82943   1       900  16  1015675  83   75   1    1  ...  93
# 951   P    89476   2       100  16  1015675  12   13   3   NA  ...  12
# ...

# %%
df = df[1:20,160:239]
#[which()]

# %%
names(df)
# Out:
#  [1] "pwgtp1"  "pwgtp2"  "pwgtp3"  "pwgtp4"  "pwgtp5"  "pwgtp6"  "pwgtp7"
#  [8] "pwgtp8"  "pwgtp9"  "pwgtp10" "pwgtp11" "pwgtp12" "pwgtp13" "pwgtp14"
# [15] "pwgtp15" "pwgtp16" "pwgtp17" "pwgtp18" "pwgtp19" "pwgtp20" "pwgtp21"
# [22] "pwgtp22" "pwgtp23" "pwgtp24" "pwgtp25" "pwgtp26" "pwgtp27" "pwgtp28"
# [29] "pwgtp29" "pwgtp30" "pwgtp31" "pwgtp32" "pwgtp33" "pwgtp34" "pwgtp35"
# [36] "pwgtp36" "pwgtp37" "pwgtp38" "pwgtp39" "pwgtp40" "pwgtp41" "pwgtp42"
# [43] "pwgtp43" "pwgtp44" "pwgtp45" "pwgtp46" "pwgtp47" "pwgtp48" "pwgtp49"
# [50] "pwgtp50" "pwgtp51" "pwgtp52" "pwgtp53" "pwgtp54" "pwgtp55" "pwgtp56"
# [57] "pwgtp57" "pwgtp58" "pwgtp59" "pwgtp60" "pwgtp61" "pwgtp62" "pwgtp63"
# [64] "pwgtp64" "pwgtp65" "pwgtp66" "pwgtp67" "pwgtp68" "pwgtp69" "pwgtp70"
# [71] "pwgtp71" "pwgtp72" "pwgtp73" "pwgtp74" "pwgtp75" "pwgtp76" "pwgtp77"
# [78] "pwgtp78" "pwgtp79" "pwgtp80"

# %%
x[which(x$var2 >8),]
# Out:
#   var1 var2 var3
# 4 1    10   11
# 5 4     9   13

# %%
df$'pwgtp1'
# Out:
#  [1]  87  88  94  91 539 192 153 232 205 226 225 109 129 115 162 190 192 185 186
# [20]  26

# %%
df[which(df$'pwgtp1' < 120),]
# Out:
#    pwgtp1 pwgtp2 pwgtp3 pwgtp4 pwgtp5 pwgtp6 pwgtp7 pwgtp8 pwgtp9 pwgtp10 ...
# 1   87     28    153     93     26     26     95     93     93     92     ...
# 2   88     30    167     96     27     25     95    100     99     90     ...
# 3   94     33    163    110     33     29    119    112    109    110     ...
# 4   91     28    161    100     28     26     98    106    106     98     ...
# 12 109    198    134     41    159    178     48    115    101     34     ...
# 14 115    158    127     44    199    224     40    130    162     33     ...
# 20  26     89     86     84     84     85    147    147    144     88     ...
#    pwgtp71 pwgtp72 pwgtp73 pwgtp74 pwgtp75 pwgtp76 pwgtp77 pwgtp78 pwgtp79
# 1   82     27       92     150      28      78      25      99     159
# 2   84     26       90     159      30      87      27      98     167
# 3   90     28       92     177      33     105      30     104     206
# ...

# %%
sort(df$"pwgtp1")
# Out:
#  [1]  26  87  88  91  94 109 115 129 153 162 185 186 190 192 192 205 225 226 232
# [20] 539

# %%
sort(df$"pwgtp1", decreasing = TRUE, na.last = TRUE)
# Out:
#  [1] 539 232 226 225 205 192 192 190 186 185 162 153 129 115 109  94  91  88  87
# [20]  26

# %%
df[order(df$pwgtp1, df$pwgtp6)]
# Out:
#    pwgtp20 pwgtp1 pwgtp2 pwgtp4 pwgtp3 pwgtp12 pwgtp14 pwgtp13 pwgtp7 pwgtp15
# 1  180      87     28     93    153    163      25      91      95    153
# 2  190      88     30     96    167    164      26      92      95    155
# 3  219      94     33    110    163    184      32     103     119    190
# 4  190      91     28    100    161    162      26      90      98    164
# 5  408     539    365    414    288    352     103     417      86    283
# 6   37     192     34    177    191    115     109     188      31     98
# 7   32     153     30    158    146     70     104     145      21     72
# 8  255     232    407    265    229    408      78     401     402    247
# 9  228     205    335    225    203    369      66     359     361    220
# 10 249     226    388    231    213    408      64     351     385    231
# 11 232     225    354    228    201    396      74     379     370    247
# 12 283     109    198     41    134     53      97     116      48    137
# ...

# %%
library(dplyr)
# Out:
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
dim(df)
# Out:
# [1] 20 80

# %%
arrange(df,pwgtp1)
# Out:
#    pwgtp1 pwgtp2 pwgtp3 pwgtp4 pwgtp5 pwgtp6 pwgtp7 pwgtp8 pwgtp9 pwgtp10 ...
# 1   26     89     86     84     84     85    147    147    144     88     ...
# 2   87     28    153     93     26     26     95     93     93     92     ...
# 3   88     30    167     96     27     25     95    100     99     90     ...
# 4   91     28    161    100     28     26     98    106    106     98     ...
# 5   94     33    163    110     33     29    119    112    109    110     ...
# 6  109    198    134     41    159    178     48    115    101     34     ...
# 7  115    158    127     44    199    224     40    130    162     33     ...
# 8  129    201    123     45    176    212     56    132    129     37     ...
# 9  153     30    146    158     83     80     21     27    157     89     ...
# 10 162    225    189     46    200    251     50    128    101     33     ...
# 11 185    176    102    108    118    100    104     36     30     31     ...
# ...

# %%
arrange(df, desc(pwgtp1) )
# Out:
#    pwgtp1 pwgtp2 pwgtp3 pwgtp4 pwgtp5 pwgtp6 pwgtp7 pwgtp8 pwgtp9 pwgtp10 ...
# 1  539    365    288    414    573    293     86    245    450    456     ...
# 2  232    407    229    265    253    246    402    251    286     67     ...
# 3  226    388    213    231    214    230    385    205    263     62     ...
# 4  225    354    201    228    237    234    370    230    240     63     ...
# 5  205    335    203    225    225    233    361    208    229     62     ...
# 6  192     34    191    177     84     96     31     33    180    118     ...
# 7  192    188    118    113    113    107    114     34     32     34     ...
# 8  190    199    125    115    113    106    116     33     31     30     ...
# 9  186    177    102    106    117    100    106     35     31     31     ...
# 10 185    176    102    108    118    100    104     36     30     31     ...
# 11 162    225    189     46    200    251     50    128    101     33     ...
# ...

# %%
df$next_col <- 10 *rnorm(5)
df$next_col
# Out:
#  [1]  5.439561  3.304796 -9.710917 -9.446847 -2.967423  5.439561  3.304796
#  [8] -9.710917 -9.446847 -2.967423  5.439561  3.304796 -9.710917 -9.446847
# [15] -2.967423  5.439561  3.304796 -9.710917 -9.446847 -2.967423

# %%
y <- cbind(df, rnorm(10))
y
# Out:
#    pwgtp1 pwgtp2 pwgtp3 pwgtp4 pwgtp5 pwgtp6 pwgtp7 pwgtp8 pwgtp9 pwgtp10 ...
# 1   87     28    153     93     26     26     95     93     93     92     ...
# 2   88     30    167     96     27     25     95    100     99     90     ...
# 3   94     33    163    110     33     29    119    112    109    110     ...
# 4   91     28    161    100     28     26     98    106    106     98     ...
# 5  539    365    288    414    573    293     86    245    450    456     ...
# 6  192     34    191    177     84     96     31     33    180    118     ...
# 7  153     30    146    158     83     80     21     27    157     89     ...
# 8  232    407    229    265    253    246    402    251    286     67     ...
# 9  205    335    203    225    225    233    361    208    229     62     ...
# 10 226    388    213    231    214    230    385    205    263     62     ...
# 11 225    354    201    228    237    234    370    230    240     63     ...
# ...

# %%
y <- cbind(df, new_col=rnorm(10))
y
# Out:
#    pwgtp1 pwgtp2 pwgtp3 pwgtp4 pwgtp5 pwgtp6 pwgtp7 pwgtp8 pwgtp9 pwgtp10 ...
# 1   87     28    153     93     26     26     95     93     93     92     ...
# 2   88     30    167     96     27     25     95    100     99     90     ...
# 3   94     33    163    110     33     29    119    112    109    110     ...
# 4   91     28    161    100     28     26     98    106    106     98     ...
# 5  539    365    288    414    573    293     86    245    450    456     ...
# 6  192     34    191    177     84     96     31     33    180    118     ...
# 7  153     30    146    158     83     80     21     27    157     89     ...
# 8  232    407    229    265    253    246    402    251    286     67     ...
# 9  205    335    203    225    225    233    361    208    229     62     ...
# 10 226    388    213    231    214    230    385    205    263     62     ...
# 11 225    354    201    228    237    234    370    230    240     63     ...
# ...

# %%
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:5: unexpected symbol
# 1: del df
#         ^
# Traceback:
